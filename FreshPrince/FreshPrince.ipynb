# %% [markdown]
# # Initial load test of Fresh Prince

# %%
import sys
print("Python executable:", sys.executable)

# test importing tsfresh
try:
    import tsfresh
    print("tsfresh imported successfully!")
except ModuleNotFoundError:
    print("tsfresh not found!")
# Out:
# Python executable: /yunity/arusty/PF-GAP/.venv/bin/python
# tsfresh imported successfully!

# %%
import os
print("Current directory contents:", os.listdir('.'))
# Out:
# Current directory contents: ['FreshPrince.py', 'FreshPrince.ipynb', '__pycache__']

# %%
from aeon.classification.feature_based import FreshPRINCEClassifier #Regressor doesn't exist yet (At least, I didn't find one with my minimal search)
import numpy as np

#Data
from aeon.datasets import load_gunpoint
from aeon.datasets import load_basic_motions

#Adjust the path
import sys
sys.path.insert(0, '/yunity/arusty/PF-GAP')

# %%
# Load Data
XTRAIN, YTRAIN = load_gunpoint(split="TRAIN")
XTEST, YTEST = load_gunpoint(split="TEST")

# XTRAIN, YTRAIN = load_basic_motions(split="TRAIN")
# XTEST, YTEST = load_basic_motions(split="TEST")

#Generate random static variables to test algorithm
XSTATIC = np.random.rand(XTRAIN.shape[0], 45)
XSTATIC_TEST = np.random.rand(XTEST.shape[0], 45)

# %%
fp = FreshPRINCEClassifier()
fp.fit(XTRAIN, YTRAIN)
# Out:
# FreshPRINCEClassifier()

# %%
fp.predict(XTEST)
# Out:
# array(['1', '2', '2', '1', '1', '2', '1', '2', '2', '2', '1', '1', '2',
#        '1', '1', '1', '1', '2', '2', '2', '1', '2', '1', '2', '1', '2',
#        '1', '1', '1', '2', '1', '2', '2', '1', '1', '1', '1', '1', '1',
#        '1', '1', '2', '1', '1', '2', '1', '2', '2', '2', '2', '2', '2',
#        '2', '2', '1', '1', '2', '2', '1', '2', '1', '2', '1', '1', '2',
#        '1', '1', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2', '2',
#        '2', '1', '1', '1', '2', '2', '2', '2', '1', '1', '1', '1', '2',
#        '2', '1', '2', '2', '1', '2', '2', '1', '1', '2', '1', '1', '2',
#        '2', '1', '1', '2', '1', '2', '2', '2', '1', '2', '1', '1', '2',
#        '1', '1', '2', '1', '2', '2', '2', '1', '2', '1', '1', '2', '2',
#        '2', '1', '1', '1', '1', '2', '1', '2', '1', '1', '2', '1', '1',
#        '2', '1', '2', '1', '2', '2', '1'], dtype='<U1')

# %% [markdown]
# # Testing Fresh Prince Gap

# %%
from FreshPrince import FreshPRINCE_GAP

fp = FreshPRINCE_GAP()
fp.fit(XTRAIN, YTRAIN, XSTATIC)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 from FreshPrince import FreshPRINCE_GAP
#       3 fp = FreshPRINCE_GAP()
# ----> 4 fp.fit(XTRAIN, YTRAIN, XSTATIC)
#
# File ~/PF-GAP/FreshPrince/FreshPrince.py:169, in FreshPRINCE_GAP.fit(self, X, y, static)
#     166 self._estimator = self._rotf
#     168 # From the proximity mixin
# --> 169 self.prox_fit(X_t, None)
#     171 self.is_fitted = True
#     173 return self
#
# File ~/PF-GAP/helpers.py:142, in ProximityMixin.prox_fit(self, X, x_test)
#     141 def prox_fit(self, X, x_test = None):
# --> 142     self.leaf_matrix = self._estimator.apply(X)
#     144     if x_test is not None:
#     145         n_test = np.shape(x_test)[0]
#
# File ~/PF-GAP/FreshPrince/FreshPrince.py:164, in FreshPRINCE_GAP.fit.<locals>.<lambda>(X)
#     161 self._rotf.fit(X_t, y)
#     163 #Implement custom built apply method
# --> 164 self._rotf.apply = lambda X: rotation_forest_apply(self._rotf, X)
#     166 self._estimator = self._rotf
#     168 # From the proximity mixin
#
# File ~/PF-GAP/FreshPrince/FreshPrince.py:39, in rotation_forest_apply(rotf, X)
#      22 """
#      23 Custom apply method for RotationForestClassifier.
#      24
#    (...)
#      36     to the leaf index of a tree in the ensemble.
#      37 """
#      38 leaf_matrix = []
# ---> 39 for tree, pca in zip(rotf.estimators_, rotf.pcas_):
#      40     # Transform the data using the PCA for this tree
#      41     X_transformed = pca.transform(X)
#      42     # Get the leaf indices from the decision tree
#
# AttributeError: 'RotationForestClassifier' object has no attribute 'pcas_'
